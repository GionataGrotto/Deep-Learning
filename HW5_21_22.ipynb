# %% [markdown]
# <a href="https://colab.research.google.com/github/GionataGrotto/Deep-Learning/blob/main/HW5_21_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Deep Learning Homework 5: *Autoencoders***
# ### MSc Computer Science, Data Science, Cybersecurity Computer Engeneering @UniPD
# ### 2nd semester - 6 ECTS
# ### Prof. Nicolò Navarin & Prof. Alessandro Sperduti
# ---
#
#
# In this homework, we will deal with _dimensionality reduction_ and learn how to develop a simple _Autoencoder_.
# In the first part, we will learn how to develop a simple shallow autoencoder, then we will develop a deep version. Next, we will experiment with the application of autoencoder on denoising data task (denoising-autoencoder). Finally, we will apply this model to sequential domains, considering the IMDB dataset seen in HW4.

# %%
# import the usual libriaries
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

np.random.seed(42)

# %% [markdown]
# ### Load Dataset
# We load the CIFAR-10 dataset, using `tf.keras.datasets`. The dataset contains 60,000 training images and 10,000 testing images.
# The images are originally in RGB format, but we will convert them to grayscale for convenience. The value of each pixel is between 0 and 255, and it represents a point of an image of size 32 x 32. We will normalize all values between 0 and 1, and we will flatten the 32x32 images into vectors of size 1024.
# Finally, since no validation set is defined, we split the test set in a validation set and a new test set.

# %%
cifar_10 = keras.datasets.cifar10
(X_train_full, _), (x_test, _) = cifar_10.load_data() # The dataset is already divede in test and training

X_train_full, x_test = np.mean(X_train_full, -1), np.mean(x_test, -1)

X_train_full = X_train_full.astype('float32') / 255
x_test = x_test.astype('float32') / 255

X_train_full = X_train_full.reshape((len(X_train_full), np.prod(X_train_full.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# We extract the first 10000 samples of the training set, to use them as the validation set
x_valid, x_train = X_train_full[:10000], X_train_full[10000:]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.1: Singular Value Decomposition
#
# Similar to Principal component analysis (PCA), Singular Value Decomposition (SVD) is a standard linear dimensionality reduction method. They both linealry combine the features of the original high-dimensional dataset and project them into a lower-dimensional space, ideally retaing most of thier intrinsic properties.
#
# In this first part of the HW, we will focus our attention on SVD decomposition and its performances. Given a matrix $X$, the SVD decomposes it into the product of two unitary matrices $V$ and $U$ and a rectangular diagonal matrix of singular values $S$:
#
# $$ X=V \cdot S \cdot U^T.$$
#
# The SVD is already implemented in NumPy as `np.linalg.svd`. In our case, the $X$ matrix will represent the training set, where each row is a sample (therefore the number of columns will be the number of input features). However, notice that the $X$ matrix has a huge number of rows (we have 50,000 input samples) and only 784 columns. If you are using the _Colab_ free plan, the quantity of available RAM may not be sufficient to compute the SVD of $X$. Therefore, to ease memory consumption and numerical stability, we resort to one property of the SVD and compute its equivalent version from the covariance matrix $C= X^T \cdot X$, that can be decomposed as:
#
# $$ C= U \cdot S^2 \cdot U^T$$
#
# Since we need just the matrix $U$ to compute the compressed version of our data, this trick turns out to be a quick and good solution.

# %%
def SVD(X, k):
  # Compute covariance matrix
  C = np.dot(X.T, X)
  # SVD decomposition
  U, s_sqr, U_T = np.linalg.svd(C, full_matrices=False)
  # Limit the number columns of U to k
  U_k=U[:,:k]
  return U_k

# %% [markdown]
# Let's define the `ENCODING_DIM`, that will be the size of the compressed version of input data, and project the low-dimensional versions of the training set and the test set as well.

# %%
ENCODING_DIM = 120

U_k = SVD(x_train, ENCODING_DIM)

x_training_svd = np.dot(x_train, U_k)
x_test_svd = np.dot(x_test, U_k)

# %% [markdown]
# We now reconstruct back the original input and check how much information was lost due to the compression. We do so by computing the mean squared error between the original input and the reconstruction, and by plotting the reconstructed images.

# %%
x_training_reco = np.dot(x_training_svd, U_k.T)
x_test_reco = np.dot(x_test_svd, U_k.T)

# %%
accuracy_train = ((x_train - x_training_reco)**2).mean()
accuracy_test = ((x_test - x_test_reco)**2).mean()

print("Training mse: %.5f" % ( accuracy_train))
print("Test mse: %.5f" % ( accuracy_test))
# Out:
# Training mse: 0.00372
# Test mse: 0.00375

# %%
def plot_img(n, images_sets: list, title=""):
  plt.figure(figsize=(20, 4))
  for i in range(n):
    for set_idx, images in enumerate(images_sets):
      ax = plt.subplot(len(images_sets), n, i + 1 + set_idx*n)
      plt.imshow(images[i].reshape(32, 32))
      plt.gray()
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)
  plt.suptitle(title)
  plt.show()

# %% [markdown]
# Let's see how well the input can be reconstructed by displaying a few of the input images and the corresponding reconstructions. Obviously, all these evaluations have to be done on the test set.
#
# The first row of images corresponds to input data, while the second one contains the reconstructions.

# %%
plot_img(10, [x_test, x_test_reco], title = "Original (top) vs Reconstructed (bottom)")

# %%
dimensions = [20, 40, 64, 120, 180, 256, 512]

for dim in dimensions:
  U_k = SVD(x_train, dim)

  x_training_svd = np.dot(x_train, U_k)
  x_test_svd = np.dot(x_test, U_k)

  x_training_reco = np.dot(x_training_svd, U_k.T)
  x_test_reco = np.dot(x_test_svd, U_k.T)

  accuracy_train = ((x_train - x_training_reco)**2).mean()
  accuracy_test = ((x_test - x_test_reco)**2).mean()

  print('Dimension: {}'.format(str(dim)))
  print("Training mse: %.5f" % ( accuracy_train))
  print("Test mse: %.5f" % ( accuracy_test))

  plot_img(10, [x_test, x_test_reco], title = "Original (top) vs Reconstructed (bottom)")
# Out:
# Dimension: 20
# Training mse: 0.01263
# Test mse: 0.01272
# Dimension: 40
# Training mse: 0.00859
# Test mse: 0.00863
# Dimension: 64
# Training mse: 0.00628
# Test mse: 0.00631
# Dimension: 120
# Training mse: 0.00372
# Test mse: 0.00375
# Dimension: 180
# Training mse: 0.00240
# Test mse: 0.00244
# Dimension: 256
# Training mse: 0.00150
# Test mse: 0.00153
# Dimension: 512
# Training mse: 0.00037
# Test mse: 0.00038

# %% [markdown]
# **[TO COMPLETE]**: What happens by varying the `ENCODING_DIM`? Try it out and discuss the results in this cell.
#
# We can see that increasing the size of the encoding dimension lead to better image reconstruction. With a small encoding dimension the images are less defined but the computation is faster.
# With a big encoding dimension more informations are saved for the phase of decoding, indeed the loss is smaller with greater encoding dimension.
#
# **Mean square error for different dimensions**
# - 20 -> 0.01272
# - 40 -> 0.00863
# - 64 -> 0.00631
# - 120 -> 0.00375
# - 180 -> 0.00244
# - 256 -> 0.00153
# - 512 -> 0.00038

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.2: Shallow Linear Autoencoder
# Let's define a model that consists of a single fully-connected neural layer. The hidden layer and the output layer act as the encoder and the decoder, respectively. Differently than the previous HW when we used `Keras.Sequential()`, here we define the two parts of the model (encoder and decoder) separately and then we create the final model.

# %%
ENCODING_DIM = 256
INPUT_DIM = x_train.shape[-1]

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
# Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='linear')(input_img)

# ...the decoder...
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='linear')(encoded)

# and the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

# In order to visualize the learned encoding, define a model that computes the 
# two parts separately.
encoder = tf.keras.models.Model(input_img, encoded)
encoded_input = tf.keras.layers.Input(shape=(ENCODING_DIM,))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input, decoder_layer(encoded_input))

# Finally, let's call the compile method
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss='mse')

# %% [markdown]
# Print the model summary.

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1024)]            0
#
#  dense (Dense)               (None, 256)               262400
#
#  dense_1 (Dense)             (None, 1024)              263168
#
# =================================================================
# Total params: 525,568
# Trainable params: 525,568
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model.

# %%
history = autoencoder.fit(x_train, x_train, epochs=15, batch_size=512, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/15
# 79/79 [==============================] - 5s 13ms/step - loss: 0.1753 - val_loss: 0.0314
# Epoch 2/15
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0378 - val_loss: 0.0210
# Epoch 3/15
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0183 - val_loss: 0.0164
# Epoch 4/15
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0149 - val_loss: 0.0142
# Epoch 5/15
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0135 - val_loss: 0.0119
# Epoch 6/15
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0110 - val_loss: 0.0105
# Epoch 7/15
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0101 - val_loss: 0.0096
# Epoch 8/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0090 - val_loss: 0.0085
# Epoch 9/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0080
# Epoch 10/15
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0093 - val_loss: 0.0078
# Epoch 11/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0067
# Epoch 12/15
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 13/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 14/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 0.0056
# Epoch 15/15
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.0055

# %% [markdown]
# Plot the loss and the accuracy curves on the validation set, and the accuracy on the test set.

# %%
def plot_loss(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['loss'])
  plt.plot(history.epoch,history.history['val_loss'])
  plt.grid()
  plt.title('loss')

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("Test mse: %.5f" % (scores))
# Out:
# 313/313 - 0s - loss: 0.0054 - 495ms/epoch - 2ms/step
# Test mse: 0.00545

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

plot_img(10, [x_test, decoded_imgs], title = "Original (top) vs Reconstructed (bottom)")

# %% [markdown]
# **[TO COMPLETE]** Check the results and compare them versus the results obtained with the SVD. Give an explanation of the relation between the results obtained  by the shallow linear autoencoder and the ones obtained by the SVD decomposition.
#
#
# _Answer:_ The error of the shallow linear autoencoder is higher respect to the SVD. It can be improved increasing the dimension of the encoding
# The mean squared error of this model is 0.00545, instead the SVD error is 0.00150 with the same encoding dimension

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.3: Shallow Non-linear Autoencoders
#
# **[TO COMPLETE]** Replicate the code of Exercise 5.2 but in this case, instead of using linear activation functions use non-linear ones. Choose the most appropriate non-linear function, and motivate your choice. Then discuss the results in relation to those obtained in Exercise 5.2.
#
# Insert your code and theoretical discussion into cells immediately below this one.

# %%
ENCODING_DIM = 256
INPUT_DIM = x_train.shape[-1]

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
# Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='sigmoid')(input_img)

# ...the decoder...
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='sigmoid')(encoded)

# and the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

# In order to visualize the learned encoding, define a model that computes the 
# two parts separately.
encoder = tf.keras.models.Model(input_img, encoded)
encoded_input = tf.keras.layers.Input(shape=(ENCODING_DIM,))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input, decoder_layer(encoded_input))

# Finally, let's call the compile method
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 1024)]            0
#
#  dense_30 (Dense)            (None, 256)               262400
#
#  dense_31 (Dense)            (None, 1024)              263168
#
# =================================================================
# Total params: 525,568
# Trainable params: 525,568
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = autoencoder.fit(x_train, x_train, epochs=15, batch_size=512, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/15
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0361 - val_loss: 0.0241
# Epoch 2/15
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0206 - val_loss: 0.0186
# Epoch 3/15
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0160 - val_loss: 0.0172
# Epoch 4/15
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0148 - val_loss: 0.0138
# Epoch 5/15
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0125 - val_loss: 0.0168
# Epoch 6/15
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0114 - val_loss: 0.0106
# Epoch 7/15
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0102 - val_loss: 0.0096
# Epoch 8/15
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0097 - val_loss: 0.0092
# Epoch 9/15
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0089 - val_loss: 0.0082
# Epoch 10/15
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0085 - val_loss: 0.0079
# Epoch 11/15
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0084 - val_loss: 0.0079
# Epoch 12/15
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 13/15
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0077 - val_loss: 0.0090
# Epoch 14/15
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0073 - val_loss: 0.0067
# Epoch 15/15
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0073 - val_loss: 0.0071

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("Test mse: %.5f" % (scores))
# Out:
# 313/313 - 1s - loss: 0.0071 - 544ms/epoch - 2ms/step
# Test mse: 0.00707

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

plot_img(10, [x_test, decoded_imgs], title = "Original (top) vs Reconstructed (bottom)")

# %% [markdown]
# _Answer:_ The non linear function with the best performance is the sigmoid, probably because is one of the best activation function to predict the output as probability. The MSE is 0.00707 so sligthly worse respect to the last model.

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.4: Deep Autoencoder
# **[TO COMPLETE]** Build a deep version of the Autoencoder defined above. The autoencoder has to use at least 5 layers. The model will use $n$ layers for encoding, and $n-1$ for decoding. The layers sizes of the encoding part decrease at each layer (e.g., `INPUT_DIM->128->64`, where 64 is the encoding dim). The decoding part layers dimensions progression turns out to be mirrored (e.g., `128->INPUT_DIM`, the final overall structure recalls an hourglass ⏳).
# As usual, print the model summary, the loss curves during the training, the achieved loss on the test set, and some input images with the corresponding decoding.

# %%
INPUT_DIM = x_train.shape[-1]

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
#encoding layers
encoded_1 = tf.keras.layers.Dense(512, activation='sigmoid')(input_img)
encoded_2 = tf.keras.layers.Dense(256, activation='tanh')(encoded_1)
#decoding layers
decoded_1 = tf.keras.layers.Dense(512, activation='tanh')(encoded_2)
decoded_2 = tf.keras.layers.Dense(INPUT_DIM, activation='sigmoid')(decoded_1)


autoencoder = tf.keras.models.Model(input_img, decoded_2) 

autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005), loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 1024)]            0
#
#  dense_4 (Dense)             (None, 512)               524800
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dense_6 (Dense)             (None, 512)               131584
#
#  dense_7 (Dense)             (None, 1024)              525312
#
# =================================================================
# Total params: 1,313,024
# Trainable params: 1,313,024
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = autoencoder.fit(x_train, x_train, epochs= 60, batch_size= 512, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/60
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0340 - val_loss: 0.0238
# Epoch 2/60
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0195 - val_loss: 0.0173
# Epoch 3/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0157 - val_loss: 0.0147
# Epoch 4/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0137 - val_loss: 0.0130
# Epoch 5/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0123 - val_loss: 0.0118
# Epoch 6/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0112 - val_loss: 0.0110
# Epoch 7/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0104 - val_loss: 0.0100
# Epoch 8/60
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 9/60
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 10/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0087 - val_loss: 0.0085
# Epoch 11/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0083 - val_loss: 0.0081
# Epoch 12/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0079 - val_loss: 0.0078
# Epoch 13/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0076 - val_loss: 0.0075
# Epoch 14/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0073 - val_loss: 0.0072
# Epoch 15/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0071 - val_loss: 0.0070
# Epoch 16/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0069
# Epoch 17/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 18/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 19/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 20/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 21/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 22/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 23/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 24/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 25/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 26/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0056
# Epoch 27/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 28/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 29/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 30/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 31/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 32/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 33/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 34/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 35/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 36/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 37/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 38/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 39/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 40/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 41/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 42/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 43/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 44/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 45/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 46/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 47/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0039 - val_loss: 0.0045
# Epoch 48/60
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 49/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 50/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 51/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 52/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 53/60
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 54/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 55/60
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 56/60
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 57/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 58/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 59/60
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 60/60
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0036

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("test mse: %.5f" % (scores))
# Out:
# 313/313 - 1s - loss: 0.0036 - 530ms/epoch - 2ms/step
# test mse: 0.00361

# %%
decoded_imgs = autoencoder.predict(x_test)

plot_img(10, [x_test, decoded_imgs], title = "Original (top) vs Reconstructed (bottom)")

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.5: Denoising Autoencoder
#
# Let's now use a shallow autoencoder to denoise the input data. The idea is that only meaningful information will be encoded, thus filtering out useless noise.
# Firstly, define a noisy input by adding some gaussian noise to our input data. We define a noise factor that can be used to modify the amount of noise to add to the input data. Check how much it influences the denoising capability of the autoencoder.

# %%
noise_factor = 0.3

x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_valid_noisy = x_valid + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_valid.shape)

# we still have to be sure that the color values are in the [0,1] range:
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
x_valid_noisy = np.clip(x_valid_noisy, 0., 1.)

# %% [markdown]
# Plot some noisy inputs:

# %%
plot_img(10, [x_test_noisy, x_test], title = "Noisy (top) vs Original (bottom)")

# %% [markdown]
# **[TO COMPLETE]** Define a shallow autoencoder able to compute a de-noised version of the input (use a noise_factor $\geq 0.3$).

# %%
INPUT_DIM = x_train.shape[-1]
ENCODING_DIM = 256

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
#[TO COMPLETE]
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='tanh')(input_img)
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='sigmoid')(encoded)

autoencoder = tf.keras.models.Model(input_img, decoded)

autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss='mse') #[TO COMPLETE]

# %%
autoencoder.summary()
# Out:
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 1024)]            0
#
#  dense_20 (Dense)            (None, 256)               262400
#
#  dense_21 (Dense)            (None, 1024)              263168
#
# =================================================================
# Total params: 525,568
# Trainable params: 525,568
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **[TO COMPLETE]** Train the model by passing the noisy input and the clean target.

# %%
history = autoencoder.fit(x_train_noisy, x_train, epochs=40, batch_size=128, shuffle=True, validation_data=(x_valid_noisy, x_valid)) #[TO COMPLETE]
# Out:
# Epoch 1/40
# 313/313 [==============================] - 2s 4ms/step - loss: 0.0275 - val_loss: 0.0175
# Epoch 2/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0172 - val_loss: 0.0172
# Epoch 3/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0159 - val_loss: 0.0152
# Epoch 4/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0168 - val_loss: 0.0158
# Epoch 5/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0157 - val_loss: 0.0171
# Epoch 6/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0137 - val_loss: 0.0131
# Epoch 7/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0144 - val_loss: 0.0145
# Epoch 8/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0139 - val_loss: 0.0131
# Epoch 9/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0130 - val_loss: 0.0135
# Epoch 10/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0139 - val_loss: 0.0131
# Epoch 11/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 12/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0129 - val_loss: 0.0139
# Epoch 13/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0130 - val_loss: 0.0131
# Epoch 14/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0126 - val_loss: 0.0139
# Epoch 15/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0128 - val_loss: 0.0125
# Epoch 16/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0126 - val_loss: 0.0123
# Epoch 17/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0126 - val_loss: 0.0126
# Epoch 18/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0127 - val_loss: 0.0129
# Epoch 19/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0125 - val_loss: 0.0128
# Epoch 20/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0126 - val_loss: 0.0126
# Epoch 21/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0124 - val_loss: 0.0124
# Epoch 22/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0125 - val_loss: 0.0130
# Epoch 23/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0123 - val_loss: 0.0135
# Epoch 24/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0125 - val_loss: 0.0127
# Epoch 25/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0123 - val_loss: 0.0127
# Epoch 26/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0123 - val_loss: 0.0143
# Epoch 27/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0124 - val_loss: 0.0130
# Epoch 28/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 29/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0123 - val_loss: 0.0133
# Epoch 30/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0122 - val_loss: 0.0123
# Epoch 31/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0122 - val_loss: 0.0133
# Epoch 32/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0122 - val_loss: 0.0127
# Epoch 33/40
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0122 - val_loss: 0.0127
# Epoch 34/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0123 - val_loss: 0.0134
# Epoch 35/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0123 - val_loss: 0.0126
# Epoch 36/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0122 - val_loss: 0.0127
# Epoch 37/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0122 - val_loss: 0.0125
# Epoch 38/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0121 - val_loss: 0.0126
# Epoch 39/40
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0124 - val_loss: 0.0123
# Epoch 40/40
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0122 - val_loss: 0.0129

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test_noisy, x_test, verbose=2)
print("Test mse: %.5f" % (scores))
# Out:
# 313/313 - 1s - loss: 0.0111 - 520ms/epoch - 2ms/step
# Test mse: 0.01112

# %% [markdown]
# **[TO COMPLETE]** Check the result by plotting some input images and the corresponding denoised outputs.

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

plot_img(10, [x_test_noisy, x_test, decoded_imgs])

# %% [markdown]
# ## Exercise 5.6: Linear Autoencoder for sequences
#
# Let's define a linear autoencoder for sequences. In this case we will use the IMDB dataset (already introduced in HW4). To have a model that can be trained and tested in a reasonable time (and that works also with the memory limitation that we have in _Colab_), we will limit the number of training samples and test samples.

# %%
num_words = 100
(X_train, _), (X_test, _) = keras.datasets.imdb.load_data(num_words=num_words)

X_train=X_train[:10000]

(X_valid, X_test) = X_test[:1250], X_test[-1250:]

word_index = keras.datasets.imdb.get_word_index()

reverse_index = {word_id + 3: word for word, word_id in word_index.items()}
reverse_index[0] = "<pad>" # padding
reverse_index[1] = "<sos>" # start of sequence
reverse_index[2] = "<oov>" # out-of-vocabulary
reverse_index[3] = "<unk>" # unknown

def decode_review(word_ids):
    return " ".join([reverse_index.get(word_id, "<err>") for word_id in word_ids])

maxlen = 90
X_train_trim = keras.preprocessing.sequence.pad_sequences(X_train, maxlen=maxlen)
X_test_trim = keras.preprocessing.sequence.pad_sequences(X_test, maxlen=maxlen)
X_valid_trim = keras.preprocessing.sequence.pad_sequences(X_valid, maxlen=maxlen)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 0s 0us/step
# 1654784/1641221 [==============================] - 0s 0us/step

# %% [markdown]
# In this case, we want to use as input/target a one-hot representation for each word. To convert the index representation provided by IMDB dataset loader we use the to_categorical method to transform them in the corresponding one hot representation.

# %%
from tensorflow.keras.utils import to_categorical


X_train_one_hot=to_categorical(X_train_trim)
X_test_one_hot=to_categorical(X_test_trim)
X_valid_one_hot=to_categorical(X_valid_trim)

# %% [markdown]
# Define a linear shallow autoencoder for sequences. The structure will be similar to the model defined in Exercise 5.2, while the used encoding layer is defined by using `tf.keras.layers.SimpleRNN`. Note that it uses linear activations. The decoding layer exploits [tf.keras.layers.TimeDistributed](https://www.tensorflow.org/api_docs/python/tf/keras/layers/TimeDistributed) that allows using the same dense cell at each time step of the sequence.

# %%
inputs = tf.keras.layers.Input(shape=(maxlen, num_words))
encoded = tf.keras.layers.SimpleRNN(50, return_sequences=True, activation='linear')(inputs)

decoded = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(num_words, activation='linear'))(encoded)

sequence_autoencoder = tf.keras.models.Model(inputs, decoded)
encoder = tf.keras.models.Model(inputs, encoded)

sequence_autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=["CategoricalAccuracy"])

sequence_autoencoder.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 90, 100)]         0
#
#  simple_rnn (SimpleRNN)      (None, 90, 50)            7550
#
#  time_distributed (TimeDistr  (None, 90, 100)          5100
#  ibuted)
#
# =================================================================
# Total params: 12,650
# Trainable params: 12,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = sequence_autoencoder.fit(X_train_one_hot, X_train_one_hot, epochs=50, batch_size=128, shuffle=True, validation_data=(X_valid_one_hot, X_valid_one_hot))
# Out:
# Epoch 1/50
# 79/79 [==============================] - 7s 70ms/step - loss: 0.2321 - categorical_accuracy: 0.0529 - val_loss: 0.1127 - val_categorical_accuracy: 0.1717
# Epoch 2/50
# 79/79 [==============================] - 5s 69ms/step - loss: 0.0898 - categorical_accuracy: 0.3233 - val_loss: 0.0746 - val_categorical_accuracy: 0.4195
# Epoch 3/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0664 - categorical_accuracy: 0.4613 - val_loss: 0.0613 - val_categorical_accuracy: 0.4746
# Epoch 4/50
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0572 - categorical_accuracy: 0.5022 - val_loss: 0.0549 - val_categorical_accuracy: 0.5089
# Epoch 5/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0518 - categorical_accuracy: 0.5264 - val_loss: 0.0506 - val_categorical_accuracy: 0.5369
# Epoch 6/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0471 - categorical_accuracy: 0.5437 - val_loss: 0.0455 - val_categorical_accuracy: 0.5370
# Epoch 7/50
# 79/79 [==============================] - 6s 81ms/step - loss: 0.0431 - categorical_accuracy: 0.5651 - val_loss: 0.0418 - val_categorical_accuracy: 0.5846
# Epoch 8/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0388 - categorical_accuracy: 0.6005 - val_loss: 0.0369 - val_categorical_accuracy: 0.6089
# Epoch 9/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0349 - categorical_accuracy: 0.6233 - val_loss: 0.0341 - val_categorical_accuracy: 0.6330
# Epoch 10/50
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0325 - categorical_accuracy: 0.6465 - val_loss: 0.0323 - val_categorical_accuracy: 0.6847
# Epoch 11/50
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0307 - categorical_accuracy: 0.6899 - val_loss: 0.0295 - val_categorical_accuracy: 0.6787
# Epoch 12/50
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0282 - categorical_accuracy: 0.6890 - val_loss: 0.0277 - val_categorical_accuracy: 0.6953
# Epoch 13/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0266 - categorical_accuracy: 0.7092 - val_loss: 0.0262 - val_categorical_accuracy: 0.7132
# Epoch 14/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0252 - categorical_accuracy: 0.7276 - val_loss: 0.0249 - val_categorical_accuracy: 0.7365
# Epoch 15/50
# 79/79 [==============================] - 6s 71ms/step - loss: 0.0241 - categorical_accuracy: 0.7521 - val_loss: 0.0239 - val_categorical_accuracy: 0.7638
# Epoch 16/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0230 - categorical_accuracy: 0.7797 - val_loss: 0.0226 - val_categorical_accuracy: 0.7888
# Epoch 17/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0220 - categorical_accuracy: 0.7968 - val_loss: 0.0216 - val_categorical_accuracy: 0.8024
# Epoch 18/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0210 - categorical_accuracy: 0.8140 - val_loss: 0.0209 - val_categorical_accuracy: 0.8219
# Epoch 19/50
# 79/79 [==============================] - 6s 70ms/step - loss: 0.0202 - categorical_accuracy: 0.8317 - val_loss: 0.0200 - val_categorical_accuracy: 0.8358
# Epoch 20/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0194 - categorical_accuracy: 0.8444 - val_loss: 0.0194 - val_categorical_accuracy: 0.8505
# Epoch 21/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0193 - categorical_accuracy: 0.8584 - val_loss: 0.0193 - val_categorical_accuracy: 0.8609
# Epoch 22/50
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0187 - categorical_accuracy: 0.8659 - val_loss: 0.0187 - val_categorical_accuracy: 0.8679
# Epoch 23/50
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0181 - categorical_accuracy: 0.8733 - val_loss: 0.0180 - val_categorical_accuracy: 0.8763
# Epoch 24/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0176 - categorical_accuracy: 0.8819 - val_loss: 0.0175 - val_categorical_accuracy: 0.8839
# Epoch 25/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0171 - categorical_accuracy: 0.8892 - val_loss: 0.0172 - val_categorical_accuracy: 0.8908
# Epoch 26/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0169 - categorical_accuracy: 0.8954 - val_loss: 0.0171 - val_categorical_accuracy: 0.8965
# Epoch 27/50
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0166 - categorical_accuracy: 0.8999 - val_loss: 0.0166 - val_categorical_accuracy: 0.9013
# Epoch 28/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0162 - categorical_accuracy: 0.9042 - val_loss: 0.0163 - val_categorical_accuracy: 0.9047
# Epoch 29/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0160 - categorical_accuracy: 0.9076 - val_loss: 0.0160 - val_categorical_accuracy: 0.9082
# Epoch 30/50
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0157 - categorical_accuracy: 0.9106 - val_loss: 0.0158 - val_categorical_accuracy: 0.9108
# Epoch 31/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0154 - categorical_accuracy: 0.9131 - val_loss: 0.0155 - val_categorical_accuracy: 0.9133
# Epoch 32/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0151 - categorical_accuracy: 0.9158 - val_loss: 0.0152 - val_categorical_accuracy: 0.9155
# Epoch 33/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0149 - categorical_accuracy: 0.9177 - val_loss: 0.0150 - val_categorical_accuracy: 0.9175
# Epoch 34/50
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0147 - categorical_accuracy: 0.9193 - val_loss: 0.0148 - val_categorical_accuracy: 0.9190
# Epoch 35/50
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0145 - categorical_accuracy: 0.9208 - val_loss: 0.0146 - val_categorical_accuracy: 0.9206
# Epoch 36/50
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0143 - categorical_accuracy: 0.9220 - val_loss: 0.0143 - val_categorical_accuracy: 0.9223
# Epoch 37/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0140 - categorical_accuracy: 0.9241 - val_loss: 0.0141 - val_categorical_accuracy: 0.9236
# Epoch 38/50
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0138 - categorical_accuracy: 0.9250 - val_loss: 0.0139 - val_categorical_accuracy: 0.9246
# Epoch 39/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0136 - categorical_accuracy: 0.9261 - val_loss: 0.0137 - val_categorical_accuracy: 0.9253
# Epoch 40/50
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0134 - categorical_accuracy: 0.9268 - val_loss: 0.0135 - val_categorical_accuracy: 0.9265
# Epoch 41/50
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0132 - categorical_accuracy: 0.9281 - val_loss: 0.0132 - val_categorical_accuracy: 0.9277
# Epoch 42/50
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0127 - categorical_accuracy: 0.9311 - val_loss: 0.0124 - val_categorical_accuracy: 0.9333
# Epoch 43/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0121 - categorical_accuracy: 0.9354 - val_loss: 0.0121 - val_categorical_accuracy: 0.9345
# Epoch 44/50
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0119 - categorical_accuracy: 0.9361 - val_loss: 0.0120 - val_categorical_accuracy: 0.9351
# Epoch 45/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0117 - categorical_accuracy: 0.9366 - val_loss: 0.0119 - val_categorical_accuracy: 0.9356
# Epoch 46/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0117 - categorical_accuracy: 0.9369 - val_loss: 0.0118 - val_categorical_accuracy: 0.9363
# Epoch 47/50
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0115 - categorical_accuracy: 0.9375 - val_loss: 0.0116 - val_categorical_accuracy: 0.9367
# Epoch 48/50
# 79/79 [==============================] - 5s 69ms/step - loss: 0.0114 - categorical_accuracy: 0.9378 - val_loss: 0.0115 - val_categorical_accuracy: 0.9370
# Epoch 49/50
# 79/79 [==============================] - 5s 69ms/step - loss: 0.0113 - categorical_accuracy: 0.9380 - val_loss: 0.0114 - val_categorical_accuracy: 0.9372
# Epoch 50/50
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0112 - categorical_accuracy: 0.9381 - val_loss: 0.0113 - val_categorical_accuracy: 0.9373

# %% [markdown]
# Let's plot the accuracy and the loss trends and check the reconstruction capability of the model by plotting the reconstruction of a test sample

# %%
def plot_categorical_accuracy(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['categorical_accuracy'])
  plt.plot(history.epoch,history.history['val_categorical_accuracy'])
  plt.title('accuracy')

plot_loss(history)

plot_categorical_accuracy(history)

scores = sequence_autoencoder.evaluate(X_test_one_hot, X_test_one_hot, verbose=2)
print("%s: %.2f%%" % (sequence_autoencoder.metrics_names[1], scores[1]*100))
# Out:
# 40/40 - 0s - loss: 0.0112 - categorical_accuracy: 0.9378 - 347ms/epoch - 9ms/step
# categorical_accuracy: 93.78%

# %%
decoded_text = sequence_autoencoder.predict(X_test_one_hot)
decode_index= np.argmax(decoded_text[500], axis=1)
input_text= np.argmax(X_test_one_hot[500], axis=1)

print(decode_review(input_text))
print(decode_review(decode_index))
# Out:
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> it there other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.7: Non-Linear Autoencoder for sequences
# **[TO COMPLETE]**: Replicate the code of the above exercise, but instead of using a simpleRNN with linear activation do the same  using  non-linear activation functions and using an LSTM layer. Choose the most appropriate non-linear function, and motivate your choice. Then discuss the results in relation to those obtained by the linear autoencoder for sequences.
#
# Hint: using a non-linear function also in the dense layer after the RNN/LSTM one will help to obtain better results. The choice of this function should be based on the type of output data.

# %%
inputs = tf.keras.layers.Input(shape=(maxlen, num_words))

encoded = tf.keras.layers.LSTM(50, return_sequences=True, activation='tanh')(inputs)
decoded = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(num_words, activation='softmax'))(encoded)

sequence_autoencoder = tf.keras.models.Model(inputs, decoded)
encoder = tf.keras.models.Model(inputs, encoded)

sequence_autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=["CategoricalAccuracy"])

sequence_autoencoder.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 90, 100)]         0
#
#  lstm (LSTM)                 (None, 90, 50)            30200
#
#  time_distributed_1 (TimeDis  (None, 90, 100)          5100
#  tributed)
#
# =================================================================
# Total params: 35,300
# Trainable params: 35,300
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = sequence_autoencoder.fit(X_train_one_hot, X_train_one_hot, epochs=50, batch_size=128, shuffle=True, validation_data=(X_valid_one_hot, X_valid_one_hot))
# Out:
# Epoch 1/50
# 79/79 [==============================] - 5s 21ms/step - loss: 0.0430 - categorical_accuracy: 0.4397 - val_loss: 0.0374 - val_categorical_accuracy: 0.4647
# Epoch 2/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0361 - categorical_accuracy: 0.4746 - val_loss: 0.0354 - val_categorical_accuracy: 0.4657
# Epoch 3/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0332 - categorical_accuracy: 0.4813 - val_loss: 0.0312 - val_categorical_accuracy: 0.4915
# Epoch 4/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0283 - categorical_accuracy: 0.5003 - val_loss: 0.0259 - val_categorical_accuracy: 0.5228
# Epoch 5/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0231 - categorical_accuracy: 0.5902 - val_loss: 0.0208 - val_categorical_accuracy: 0.6416
# Epoch 6/50
# 79/79 [==============================] - 1s 14ms/step - loss: 0.0182 - categorical_accuracy: 0.7086 - val_loss: 0.0162 - val_categorical_accuracy: 0.7549
# Epoch 7/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0141 - categorical_accuracy: 0.7922 - val_loss: 0.0125 - val_categorical_accuracy: 0.8201
# Epoch 8/50
# 79/79 [==============================] - 1s 14ms/step - loss: 0.0108 - categorical_accuracy: 0.8470 - val_loss: 0.0096 - val_categorical_accuracy: 0.8621
# Epoch 9/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0083 - categorical_accuracy: 0.8843 - val_loss: 0.0073 - val_categorical_accuracy: 0.9006
# Epoch 10/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0063 - categorical_accuracy: 0.9278 - val_loss: 0.0056 - val_categorical_accuracy: 0.9464
# Epoch 11/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0048 - categorical_accuracy: 0.9633 - val_loss: 0.0042 - val_categorical_accuracy: 0.9805
# Epoch 12/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0035 - categorical_accuracy: 0.9849 - val_loss: 0.0031 - val_categorical_accuracy: 0.9881
# Epoch 13/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0026 - categorical_accuracy: 0.9900 - val_loss: 0.0022 - val_categorical_accuracy: 0.9920
# Epoch 14/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0019 - categorical_accuracy: 0.9949 - val_loss: 0.0016 - val_categorical_accuracy: 0.9973
# Epoch 15/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0014 - categorical_accuracy: 0.9991 - val_loss: 0.0012 - val_categorical_accuracy: 0.9998
# Epoch 16/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0010 - categorical_accuracy: 0.9999 - val_loss: 9.2149e-04 - val_categorical_accuracy: 0.9999
# Epoch 17/50
# 79/79 [==============================] - 1s 14ms/step - loss: 8.0012e-04 - categorical_accuracy: 0.9999 - val_loss: 7.1588e-04 - val_categorical_accuracy: 1.0000
# Epoch 18/50
# 79/79 [==============================] - 1s 14ms/step - loss: 6.2880e-04 - categorical_accuracy: 1.0000 - val_loss: 5.6910e-04 - val_categorical_accuracy: 1.0000
# Epoch 19/50
# 79/79 [==============================] - 1s 14ms/step - loss: 5.0530e-04 - categorical_accuracy: 1.0000 - val_loss: 4.6222e-04 - val_categorical_accuracy: 1.0000
# Epoch 20/50
# 79/79 [==============================] - 1s 14ms/step - loss: 4.1442e-04 - categorical_accuracy: 1.0000 - val_loss: 3.8271e-04 - val_categorical_accuracy: 1.0000
# Epoch 21/50
# 79/79 [==============================] - 1s 14ms/step - loss: 3.4618e-04 - categorical_accuracy: 1.0000 - val_loss: 3.2224e-04 - val_categorical_accuracy: 1.0000
# Epoch 22/50
# 79/79 [==============================] - 1s 14ms/step - loss: 2.9370e-04 - categorical_accuracy: 1.0000 - val_loss: 2.7519e-04 - val_categorical_accuracy: 1.0000
# Epoch 23/50
# 79/79 [==============================] - 1s 14ms/step - loss: 2.5246e-04 - categorical_accuracy: 1.0000 - val_loss: 2.3781e-04 - val_categorical_accuracy: 1.0000
# Epoch 24/50
# 79/79 [==============================] - 1s 14ms/step - loss: 2.1935e-04 - categorical_accuracy: 1.0000 - val_loss: 2.0756e-04 - val_categorical_accuracy: 1.0000
# Epoch 25/50
# 79/79 [==============================] - 1s 14ms/step - loss: 1.9239e-04 - categorical_accuracy: 1.0000 - val_loss: 1.8271e-04 - val_categorical_accuracy: 1.0000
# Epoch 26/50
# 79/79 [==============================] - 1s 14ms/step - loss: 1.7010e-04 - categorical_accuracy: 1.0000 - val_loss: 1.6207e-04 - val_categorical_accuracy: 1.0000
# Epoch 27/50
# 79/79 [==============================] - 1s 14ms/step - loss: 1.5142e-04 - categorical_accuracy: 1.0000 - val_loss: 1.4468e-04 - val_categorical_accuracy: 1.0000
# Epoch 28/50
# 79/79 [==============================] - 1s 14ms/step - loss: 1.3562e-04 - categorical_accuracy: 1.0000 - val_loss: 1.2991e-04 - val_categorical_accuracy: 1.0000
# Epoch 29/50
# 79/79 [==============================] - 1s 14ms/step - loss: 1.2212e-04 - categorical_accuracy: 1.0000 - val_loss: 1.1723e-04 - val_categorical_accuracy: 1.0000
# Epoch 30/50
# 79/79 [==============================] - 1s 14ms/step - loss: 1.1049e-04 - categorical_accuracy: 1.0000 - val_loss: 1.0625e-04 - val_categorical_accuracy: 1.0000
# Epoch 31/50
# 79/79 [==============================] - 1s 14ms/step - loss: 1.0039e-04 - categorical_accuracy: 1.0000 - val_loss: 9.6718e-05 - val_categorical_accuracy: 1.0000
# Epoch 32/50
# 79/79 [==============================] - 1s 14ms/step - loss: 9.1577e-05 - categorical_accuracy: 1.0000 - val_loss: 8.8350e-05 - val_categorical_accuracy: 1.0000
# Epoch 33/50
# 79/79 [==============================] - 1s 14ms/step - loss: 8.3819e-05 - categorical_accuracy: 1.0000 - val_loss: 8.0974e-05 - val_categorical_accuracy: 1.0000
# Epoch 34/50
# 79/79 [==============================] - 1s 13ms/step - loss: 7.6963e-05 - categorical_accuracy: 1.0000 - val_loss: 7.4451e-05 - val_categorical_accuracy: 1.0000
# Epoch 35/50
# 79/79 [==============================] - 1s 13ms/step - loss: 7.0883e-05 - categorical_accuracy: 1.0000 - val_loss: 6.8643e-05 - val_categorical_accuracy: 1.0000
# Epoch 36/50
# 79/79 [==============================] - 1s 14ms/step - loss: 6.5454e-05 - categorical_accuracy: 1.0000 - val_loss: 6.3458e-05 - val_categorical_accuracy: 1.0000
# Epoch 37/50
# 79/79 [==============================] - 1s 14ms/step - loss: 6.0591e-05 - categorical_accuracy: 1.0000 - val_loss: 5.8793e-05 - val_categorical_accuracy: 1.0000
# Epoch 38/50
# 79/79 [==============================] - 1s 14ms/step - loss: 5.6210e-05 - categorical_accuracy: 1.0000 - val_loss: 5.4590e-05 - val_categorical_accuracy: 1.0000
# Epoch 39/50
# 79/79 [==============================] - 1s 14ms/step - loss: 5.2256e-05 - categorical_accuracy: 1.0000 - val_loss: 5.0795e-05 - val_categorical_accuracy: 1.0000
# Epoch 40/50
# 79/79 [==============================] - 1s 14ms/step - loss: 4.8668e-05 - categorical_accuracy: 1.0000 - val_loss: 4.7346e-05 - val_categorical_accuracy: 1.0000
# Epoch 41/50
# 79/79 [==============================] - 1s 13ms/step - loss: 4.5409e-05 - categorical_accuracy: 1.0000 - val_loss: 4.4203e-05 - val_categorical_accuracy: 1.0000
# Epoch 42/50
# 79/79 [==============================] - 1s 14ms/step - loss: 4.2440e-05 - categorical_accuracy: 1.0000 - val_loss: 4.1343e-05 - val_categorical_accuracy: 1.0000
# Epoch 43/50
# 79/79 [==============================] - 1s 14ms/step - loss: 3.9730e-05 - categorical_accuracy: 1.0000 - val_loss: 3.8733e-05 - val_categorical_accuracy: 1.0000
# Epoch 44/50
# 79/79 [==============================] - 1s 14ms/step - loss: 3.7245e-05 - categorical_accuracy: 1.0000 - val_loss: 3.6331e-05 - val_categorical_accuracy: 1.0000
# Epoch 45/50
# 79/79 [==============================] - 1s 14ms/step - loss: 3.4962e-05 - categorical_accuracy: 1.0000 - val_loss: 3.4125e-05 - val_categorical_accuracy: 1.0000
# Epoch 46/50
# 79/79 [==============================] - 1s 14ms/step - loss: 3.2861e-05 - categorical_accuracy: 1.0000 - val_loss: 3.2096e-05 - val_categorical_accuracy: 1.0000
# Epoch 47/50
# 79/79 [==============================] - 1s 14ms/step - loss: 3.0923e-05 - categorical_accuracy: 1.0000 - val_loss: 3.0217e-05 - val_categorical_accuracy: 1.0000
# Epoch 48/50
# 79/79 [==============================] - 1s 14ms/step - loss: 2.9131e-05 - categorical_accuracy: 1.0000 - val_loss: 2.8487e-05 - val_categorical_accuracy: 1.0000
# Epoch 49/50
# 79/79 [==============================] - 1s 14ms/step - loss: 2.7471e-05 - categorical_accuracy: 1.0000 - val_loss: 2.6880e-05 - val_categorical_accuracy: 1.0000
# Epoch 50/50
# 79/79 [==============================] - 1s 14ms/step - loss: 2.5932e-05 - categorical_accuracy: 1.0000 - val_loss: 2.5389e-05 - val_categorical_accuracy: 1.0000

# %%
def plot_categorical_accuracy(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['categorical_accuracy'])
  plt.plot(history.epoch,history.history['val_categorical_accuracy'])
  plt.title('accuracy')

plot_loss(history)

plot_categorical_accuracy(history)

scores = sequence_autoencoder.evaluate(X_test_one_hot, X_test_one_hot, verbose=2)
print("%s: %.2f%%" % (sequence_autoencoder.metrics_names[1], scores[1]*100))
# Out:
# 40/40 - 0s - loss: 2.5130e-05 - categorical_accuracy: 1.0000 - 179ms/epoch - 4ms/step
# categorical_accuracy: 100.00%

# %%
decoded_text = sequence_autoencoder.predict(X_test_one_hot)
decode_index = np.argmax(decoded_text[500], axis=1)
input_text = np.argmax(X_test_one_hot[500], axis=1)

print(decode_review(input_text))
print(decode_review(decode_index))
# Out:
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>

# %% [markdown]
# The first model where I use a simple RNN with linear activation the accuracy is equal to 93.78% instead the model with LSTM and non-linear activation the accuracy is equal to 100%.
#
# With the non linear activation function the model can detect more characteristic of the input respect to the model with the linear activation.
#
# I chose to use the hyperbolic tangent in the encoding layer instead of the sigmoid function because it copes better the of the vanishing gradient.
#
# In the decoding layer I choose to use the softmax activation function because the model must choose the most relevant word as output.
